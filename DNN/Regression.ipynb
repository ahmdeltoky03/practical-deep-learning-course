# %% [markdown]
# ## This Notebook Solve Simple Regression Task

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/Airline_Delay_Cause.csv")

# %%
data
# Out:
#         year  month carrier          carrier_name airport  \
# 0       2022      5      9E     Endeavor Air Inc.     ABE
# 1       2022      5      9E     Endeavor Air Inc.     ABY
# 2       2022      5      9E     Endeavor Air Inc.     ACK
# 3       2022      5      9E     Endeavor Air Inc.     AEX
# 4       2022      5      9E     Endeavor Air Inc.     AGS
# ...      ...    ...     ...                   ...     ...
# 318012  2003      6      DL  Delta Air Lines Inc.     SEA
# 318013  2003      6      DL  Delta Air Lines Inc.     SFO
# 318014  2003      6      DL  Delta Air Lines Inc.     SJC
# 318015  2003      6      DL  Delta Air Lines Inc.     SJU
# 318016  2003      6      DL  Delta Air Lines Inc.     SLC
#
#                                              airport_name  arr_flights  \
# 0       Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0
# 1                  Albany, GA: Southwest Georgia Regional         91.0
# 2                       Nantucket, MA: Nantucket Memorial         19.0
# 3                Alexandria, LA: Alexandria International         88.0
# 4             Augusta, GA: Augusta Regional at Bush Field        181.0
# ...                                                   ...          ...
# 318012          Seattle, WA: Seattle/Tacoma International        480.0
# 318013     San Francisco, CA: San Francisco International        505.0
# 318014  San Jose, CA: Norman Y. Mineta San Jose Intern...        146.0
# 318015       San Juan, PR: Luis Munoz Marin International         95.0
# 318016   Salt Lake City, UT: Salt Lake City International       3466.0
#
#         arr_del15  carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  \
# 0             7.0        5.95        0.00  ...          0.0              1.00
# 1            16.0        7.38        0.00  ...          0.0              6.09
# 2             2.0        0.13        0.00  ...          0.0              0.88
# 3            14.0        7.26        0.76  ...          0.0              1.64
# 4            19.0       13.84        0.00  ...          0.0              2.09
# ...           ...         ...         ...  ...          ...               ...
# 318012       84.0       25.69        3.09  ...          0.0             21.26
# 318013      111.0       21.78        2.24  ...          0.0             13.17
# 318014       36.0        6.99        0.00  ...          0.0              2.15
# 318015       13.0        3.66        0.00  ...          0.0              1.42
# 318016      454.0      121.15        7.61  ...          1.0            102.33
#
#         arr_cancelled  arr_diverted  arr_delay  carrier_delay  weather_delay  \
# 0                 0.0           0.0      255.0          222.0            0.0
# 1                 0.0           0.0      884.0          351.0            0.0
# 2                 1.0           0.0      138.0            4.0            0.0
# 3                 0.0           0.0      947.0          585.0           35.0
# 4                 0.0           0.0      808.0          662.0            0.0
# ...               ...           ...        ...            ...            ...
# 318012            0.0           0.0     3744.0          978.0          164.0
# 318013            3.0           0.0     4284.0         1376.0          138.0
# 318014            0.0           0.0      896.0          205.0            0.0
# 318015            0.0           0.0      367.0          120.0            0.0
# 318016            9.0           0.0    16853.0         5384.0          306.0
#
#         nas_delay  security_delay  late_aircraft_delay
# 0             4.0             0.0                 29.0
# 1            81.0             0.0                452.0
# 2           106.0             0.0                 28.0
# 3           125.0             0.0                202.0
# 4            87.0             0.0                 59.0
# ...           ...             ...                  ...
# 318012     1023.0             0.0               1579.0
# 318013     2132.0             0.0                638.0
# 318014      607.0             0.0                 84.0
# 318015      210.0             0.0                 37.0
# 318016     5686.0            28.0               5449.0
#
# [318017 rows x 21 columns]

# %%
# statistical information about data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
#  14  arr_diverted         317527 non-null  float64
#  15  arr_delay            317523 non-null  float64
#  16  carrier_delay        317525 non-null  float64
#  17  weather_delay        317529 non-null  float64
#  18  nas_delay            317529 non-null  float64
#  19  security_delay       317527 non-null  float64
#  20  late_aircraft_delay  317529 non-null  float64
# dtypes: float64(15), int64(2), object(4)
# memory usage: 51.0+ MB

# %%
# drop categorical variable
data = data.drop(["carrier", "carrier_name", "airport", "airport_name"],axis=1)
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [318017 rows x 17 columns]

# %%
# dropna
data.dropna(inplace=True)

# %%
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      5        136.0        7.0        5.95        0.00    0.05
# 1       2022      5         91.0       16.0        7.38        0.00    2.54
# 2       2022      5         19.0        2.0        0.13        0.00    1.00
# 3       2022      5         88.0       14.0        7.26        0.76    4.35
# 4       2022      5        181.0       19.0       13.84        0.00    3.07
# ...      ...    ...          ...        ...         ...         ...     ...
# 318012  2003      6        480.0       84.0       25.69        3.09   33.96
# 318013  2003      6        505.0      111.0       21.78        2.24   73.81
# 318014  2003      6        146.0       36.0        6.99        0.00   26.85
# 318015  2003      6         95.0       13.0        3.66        0.00    7.92
# 318016  2003      6       3466.0      454.0      121.15        7.61  221.91
#
#         security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0               0.0              1.00            0.0           0.0      255.0
# 1               0.0              6.09            0.0           0.0      884.0
# 2               0.0              0.88            1.0           0.0      138.0
# 3               0.0              1.64            0.0           0.0      947.0
# 4               0.0              2.09            0.0           0.0      808.0
# ...             ...               ...            ...           ...        ...
# 318012          0.0             21.26            0.0           0.0     3744.0
# 318013          0.0             13.17            3.0           0.0     4284.0
# 318014          0.0              2.15            0.0           0.0      896.0
# 318015          0.0              1.42            0.0           0.0      367.0
# 318016          1.0            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [317268 rows x 17 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317268 entries, 0 to 318016
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 317268 non-null  int64
#  1   month                317268 non-null  int64
#  2   arr_flights          317268 non-null  float64
#  3   arr_del15            317268 non-null  float64
#  4   carrier_ct           317268 non-null  float64
#  5   weather_ct           317268 non-null  float64
#  6   nas_ct               317268 non-null  float64
#  7   security_ct          317268 non-null  float64
#  8   late_aircraft_ct     317268 non-null  float64
#  9   arr_cancelled        317268 non-null  float64
#  10  arr_diverted         317268 non-null  float64
#  11  arr_delay            317268 non-null  float64
#  12  carrier_delay        317268 non-null  float64
#  13  weather_delay        317268 non-null  float64
#  14  nas_delay            317268 non-null  float64
#  15  security_delay       317268 non-null  float64
#  16  late_aircraft_delay  317268 non-null  float64
# dtypes: float64(15), int64(2)
# memory usage: 43.6 MB

# %%
x = data.drop("arr_flights", axis=1)
y = data["arr_flights"]

# %%
x
# Out:
#         year  month  arr_del15  carrier_ct  weather_ct  nas_ct  security_ct  \
# 0       2022      5        7.0        5.95        0.00    0.05          0.0
# 1       2022      5       16.0        7.38        0.00    2.54          0.0
# 2       2022      5        2.0        0.13        0.00    1.00          0.0
# 3       2022      5       14.0        7.26        0.76    4.35          0.0
# 4       2022      5       19.0       13.84        0.00    3.07          0.0
# ...      ...    ...        ...         ...         ...     ...          ...
# 318012  2003      6       84.0       25.69        3.09   33.96          0.0
# 318013  2003      6      111.0       21.78        2.24   73.81          0.0
# 318014  2003      6       36.0        6.99        0.00   26.85          0.0
# 318015  2003      6       13.0        3.66        0.00    7.92          0.0
# 318016  2003      6      454.0      121.15        7.61  221.91          1.0
#
#         late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0                   1.00            0.0           0.0      255.0
# 1                   6.09            0.0           0.0      884.0
# 2                   0.88            1.0           0.0      138.0
# 3                   1.64            0.0           0.0      947.0
# 4                   2.09            0.0           0.0      808.0
# ...                  ...            ...           ...        ...
# 318012             21.26            0.0           0.0     3744.0
# 318013             13.17            3.0           0.0     4284.0
# 318014              2.15            0.0           0.0      896.0
# 318015              1.42            0.0           0.0      367.0
# 318016            102.33            9.0           0.0    16853.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 0               222.0            0.0        4.0             0.0
# 1               351.0            0.0       81.0             0.0
# 2                 4.0            0.0      106.0             0.0
# 3               585.0           35.0      125.0             0.0
# 4               662.0            0.0       87.0             0.0
# ...               ...            ...        ...             ...
# 318012          978.0          164.0     1023.0             0.0
# 318013         1376.0          138.0     2132.0             0.0
# 318014          205.0            0.0      607.0             0.0
# 318015          120.0            0.0      210.0             0.0
# 318016         5384.0          306.0     5686.0            28.0
#
#         late_aircraft_delay
# 0                      29.0
# 1                     452.0
# 2                      28.0
# 3                     202.0
# 4                      59.0
# ...                     ...
# 318012               1579.0
# 318013                638.0
# 318014                 84.0
# 318015                 37.0
# 318016               5449.0
#
# [317268 rows x 16 columns]

# %%
y
# Out:
# 0          136.0
# 1           91.0
# 2           19.0
# 3           88.0
# 4          181.0
#            ...
# 318012     480.0
# 318013     505.0
# 318014     146.0
# 318015      95.0
# 318016    3466.0
# Name: arr_flights, Length: 317268, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 42)

# %%
print("x_train shape : ",x_train.shape)
print("x_test shape : ",x_test.shape)
print("y_train shape : ",y_train.shape)
print("y_test shape : ",y_test.shape)
# Out:
# x_train shape :  (253814, 16)
# x_test shape :  (63454, 16)
# y_train shape :  (253814,)
# y_test shape :  (63454,)

# %%
import tensorflow as tf
import keras

# %%
KerasModel = keras.models.Sequential([
             keras.layers.Dense(8, activation = "tanh"),
            #  keras.layers.Dropout(0.1),
             keras.layers.Dense(128, activation = "tanh"),
            #  keras.layers.Dropout(0.3),
             keras.layers.Dense(64, activation = "tanh"),
             keras.layers.Dropout(0.2),
             keras.layers.Dense(1, activation = "linear")
             ])

# %%
KerasModel.compile(optimizer="adam", loss="mse", metrics = ["mse"])

# %%
history = KerasModel.fit(
          x_train, y_train,
          validation_data = (x_test, y_test),
          epochs = 100,
          batch_size = 128, # 1
          verbose = 1,
          callbacks = [tf.keras.callbacks.EarlyStopping(
              patience = 5,
              monitor = "val_loss",
              restore_best_weights = True
          )]
        )
# Out:
# Epoch 1/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 1168343.1250 - mse: 1168343.1250 - val_loss: 1093059.6250 - val_mse: 1093059.6250
# Epoch 2/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 1127644.3750 - mse: 1127644.3750 - val_loss: 1036742.3125 - val_mse: 1036742.3125
# Epoch 3/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 1060985.7500 - mse: 1060985.7500 - val_loss: 987437.8750 - val_mse: 987437.8750
# Epoch 4/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 23s 8ms/step - loss: 1025791.1875 - mse: 1025791.1875 - val_loss: 943410.5000 - val_mse: 943410.5000
# Epoch 5/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 942050.0625 - mse: 942050.0625 - val_loss: 903669.6250 - val_mse: 903669.6250
# Epoch 6/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 927453.4375 - mse: 927453.4375 - val_loss: 866636.7500 - val_mse: 866636.7500
# Epoch 7/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 903863.0000 - mse: 903863.0000 - val_loss: 834697.1875 - val_mse: 834697.1875
# Epoch 8/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 858761.5625 - mse: 858761.5625 - val_loss: 799183.8125 - val_mse: 799183.8125
# Epoch 9/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 820549.5625 - mse: 820549.5625 - val_loss: 773073.6875 - val_mse: 773073.6875
# Epoch 10/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 829095.2500 - mse: 829095.2500 - val_loss: 740151.1875 - val_mse: 740151.1875
# Epoch 11/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 25s 8ms/step - loss: 742545.1875 - mse: 742545.1875 - val_loss: 712919.3125 - val_mse: 712919.3125
# Epoch 12/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 762794.5625 - mse: 762794.5625 - val_loss: 694819.0625 - val_mse: 694819.0625
# Epoch 13/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - loss: 706626.6875 - mse: 706626.6875 - val_loss: 677086.1250 - val_mse: 677086.1250
# Epoch 14/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 672528.8125 - mse: 672528.8125 - val_loss: 646438.6875 - val_mse: 646438.6875
# Epoch 15/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 675112.8125 - mse: 675112.8125 - val_loss: 626150.8750 - val_mse: 626150.8750
# Epoch 16/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step - loss: 646885.8125 - mse: 646885.8125 - val_loss: 619281.0000 - val_mse: 619281.0000
# Epoch 17/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - loss: 618006.0625 - mse: 618006.0625 - val_loss: 584409.2500 - val_mse: 584409.2500
# Epoch 18/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 18s 6ms/step - loss: 637071.3750 - mse: 637071.3750 - val_loss: 582253.5000 - val_mse: 582253.5000
# Epoch 19/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 633814.3750 - mse: 633814.3750 - val_loss: 569213.5625 - val_mse: 569213.5625
# Epoch 20/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 579124.6250 - mse: 579124.6250 - val_loss: 538137.3750 - val_mse: 538137.3750
# Epoch 21/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 598707.6875 - mse: 598707.6875 - val_loss: 552846.8125 - val_mse: 552846.8125
# Epoch 22/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 552831.6250 - mse: 552831.6250 - val_loss: 513677.3125 - val_mse: 513677.3125
# Epoch 23/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 23s 7ms/step - loss: 545178.7500 - mse: 545178.7500 - val_loss: 501740.1562 - val_mse: 501740.1562
# Epoch 24/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 15s 7ms/step - loss: 553071.6875 - mse: 553071.6875 - val_loss: 485078.2188 - val_mse: 485078.2188
# Epoch 25/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 519532.0938 - mse: 519532.0938 - val_loss: 476979.6875 - val_mse: 476979.6875
# Epoch 26/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 517733.6562 - mse: 517733.6562 - val_loss: 505362.4062 - val_mse: 505362.4062
# Epoch 27/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 543187.0000 - mse: 543187.0000 - val_loss: 495686.7188 - val_mse: 495686.7188
# Epoch 28/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - loss: 526910.0625 - mse: 526910.0625 - val_loss: 450971.3438 - val_mse: 450971.3438
# Epoch 29/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - loss: 460120.0312 - mse: 460120.0312 - val_loss: 441016.4375 - val_mse: 441016.4375
# Epoch 30/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 468247.4688 - mse: 468247.4688 - val_loss: 459103.9062 - val_mse: 459103.9062
# Epoch 31/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - loss: 502013.8438 - mse: 502013.8438 - val_loss: 478440.7188 - val_mse: 478440.7188
# Epoch 32/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 502430.6250 - mse: 502430.6250 - val_loss: 448487.6562 - val_mse: 448487.6562
# Epoch 33/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 446597.5938 - mse: 446597.5938 - val_loss: 417578.6562 - val_mse: 417578.6562
# Epoch 34/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 438529.5000 - mse: 438529.5000 - val_loss: 408520.3438 - val_mse: 408520.3438
# Epoch 35/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 440348.8438 - mse: 440348.8438 - val_loss: 405114.3438 - val_mse: 405114.3438
# Epoch 36/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 451019.5625 - mse: 451019.5625 - val_loss: 442190.1250 - val_mse: 442190.1250
# Epoch 37/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - loss: 437799.0000 - mse: 437799.0000 - val_loss: 448384.3438 - val_mse: 448384.3438
# Epoch 38/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 476649.0000 - mse: 476649.0000 - val_loss: 391710.5625 - val_mse: 391710.5625
# Epoch 39/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - loss: 409972.7500 - mse: 409972.7500 - val_loss: 391075.2188 - val_mse: 391075.2188
# Epoch 40/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 444136.1562 - mse: 444136.1562 - val_loss: 379493.0000 - val_mse: 379493.0000
# Epoch 41/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 23s 6ms/step - loss: 386583.6875 - mse: 386583.6875 - val_loss: 375851.2500 - val_mse: 375851.2500
# Epoch 42/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 424768.6562 - mse: 424768.6562 - val_loss: 397846.7500 - val_mse: 397846.7500
# Epoch 43/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 425749.4375 - mse: 425749.4375 - val_loss: 387713.4062 - val_mse: 387713.4062
# Epoch 44/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 401010.1875 - mse: 401010.1875 - val_loss: 367404.7188 - val_mse: 367404.7188
# Epoch 45/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 399419.3125 - mse: 399419.3125 - val_loss: 368496.6875 - val_mse: 368496.6875
# Epoch 46/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 402637.4375 - mse: 402637.4375 - val_loss: 376058.9375 - val_mse: 376058.9375
# Epoch 47/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 22s 6ms/step - loss: 403202.4688 - mse: 403202.4688 - val_loss: 361221.3750 - val_mse: 361221.3750
# Epoch 48/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 394320.6562 - mse: 394320.6562 - val_loss: 350120.8750 - val_mse: 350120.8750
# Epoch 49/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - loss: 413674.9688 - mse: 413674.9688 - val_loss: 432817.2812 - val_mse: 432817.2812
# Epoch 50/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 412572.4062 - mse: 412572.4062 - val_loss: 373322.0625 - val_mse: 373322.0625
# Epoch 51/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 455609.5000 - mse: 455609.5000 - val_loss: 362786.0000 - val_mse: 362786.0000
# Epoch 52/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 441330.6562 - mse: 441330.6562 - val_loss: 361474.4062 - val_mse: 361474.4062
# Epoch 53/100
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 442735.0625 - mse: 442735.0625 - val_loss: 411557.8125 - val_mse: 411557.8125

# %%
print(KerasModel.summary())
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 128)            │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,829 (112.62 KB)
#  Trainable params: 9,609 (37.54 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 19,220 (75.08 KB)
# None

# %%
KerasModel.save("KerasModel.keras")

# %%
UploadedModel = keras.models.load_model("KerasModel.keras")

# %%
y_pred = KerasModel.predict(x_test)
# Out:
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
ModelLoss, ModelAccuracy = KerasModel.evaluate(x_test, y_test)
print("Model Loss : ", ModelLoss)
print("Model Accuracy : ", ModelAccuracy)
# Out:
# 1983/1983 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 326219.4375 - mse: 326219.4375
# Model Loss :  350121.375
# Model Accuracy :  350121.375

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["train", "validation"], loc="upper left")
plt.show()

# %%
len(y_pred), len(y_test)
# Out:
# (63454, 63454)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 350120.9404692262
# Mean Absolute Error: 217.31713799350888
# R-squared: 0.6602896470137646

# %% [markdown]
# ## Neural Network is not preferred for Regression Task
