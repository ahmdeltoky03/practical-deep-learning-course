# %%
import nltk
nltk.download("punkt")
nltk.download("wordnet")

from nltk.stem.porter import *

p_stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
words = ['run','runner','running','ran','runs','easily','fairly']

for word in words:
  print(word,':',p_stemmer.stem(word))
# Out:
# run : run
# runner : runner
# running : run
# ran : ran
# runs : run
# easily : easili
# fairly : fairli

# %%
from nltk.stem.snowball import SnowballStemmer

s_stemmer = SnowballStemmer(language="english")


words = ['run','runner','running','ran','runs','easily','fairly']
for word in words:
  print(word,':', s_stemmer.stem(word))
# Out:
# run : run
# runner : runner
# running : run
# ran : ran
# runs : run
# easily : easili
# fairly : fair

# %%
from nltk.stem.porter import *
from nltk.stem.snowball import SnowballStemmer

p_stemmer = PorterStemmer()
s_stemmer = SnowballStemmer(language="english")


words = ['generous','generation','generously','generate']


for word in words:
    print(word+' --> '+s_stemmer.stem(word))
    print(word+' --> '+p_stemmer.stem(word))
    print('---------------------------------------')
# Out:
# generous --> generous
# generous --> gener
# ---------------------------------------
# generation --> generat
# generation --> gener
# ---------------------------------------
# generously --> generous
# generously --> gener
# ---------------------------------------
# generate --> generat
# generate --> gener
# ---------------------------------------

# %%
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()
ls = LancasterStemmer()

# %%
words = ["is","was","be","been","are","were"]

# %%
for word in words:
  print(f'word {word} has stemming {ls.stem(word)}')
# Out:
# word is has stemming is
# word was has stemming was
# word be has stemming be
# word been has stemming been
# word are has stemming ar
# word were has stemming wer

# %%
for word in words:
  print(f'word {word} has stemming {ps.stem(word)}')
# Out:
# word is has stemming is
# word was has stemming wa
# word be has stemming be
# word been has stemming been
# word are has stemming are
# word were has stemming were

# %%
words = ["book","booking","booked","books","booker","bookstore"]

# %%
for word in words:
  print(f'word {word} has stemming {ls.stem(word)}')
# Out:
# word book has stemming book
# word booking has stemming book
# word booked has stemming book
# word books has stemming book
# word booker has stemming book
# word bookstore has stemming bookst

# %%
for word in words:
  print(f'word {word} has stemming {ps.stem(word)}')
# Out:
# word book has stemming book
# word booking has stemming book
# word booked has stemming book
# word books has stemming book
# word booker has stemming booker
# word bookstore has stemming bookstor

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sentence = 'had you booked the air booking yet ? if not try to book it ASAP since booking will be out of books'

# %%
words = word_tokenize(sentence)

# %%
words
# Out:
# ['had',
#  'you',
#  'booked',
#  'the',
#  'air',
#  'booking',
#  'yet',
#  '?',
#  'if',
#  'not',
#  'try',
#  'to',
#  'book',
#  'it',
#  'ASAP',
#  'since',
#  'booking',
#  'will',
#  'be',
#  'out',
#  'of',
#  'books']

# %%
for word in words:
  print(f'word {word} has stemming {ls.stem(word)}')
# Out:
# word had has stemming had
# word you has stemming you
# word booked has stemming book
# word the has stemming the
# word air has stemming air
# word booking has stemming book
# word yet has stemming yet
# word ? has stemming ?
# word if has stemming if
# word not has stemming not
# word try has stemming try
# word to has stemming to
# word book has stemming book
# word it has stemming it
# word ASAP has stemming asap
# word since has stemming sint
# word booking has stemming book
# word will has stemming wil
# word be has stemming be
# word out has stemming out
# word of has stemming of
# word books has stemming book

# %%
for word in words:
  print(f'word {word} has stemming {ps.stem(word)}')
# Out:
# word had has stemming had
# word you has stemming you
# word booked has stemming book
# word the has stemming the
# word air has stemming air
# word booking has stemming book
# word yet has stemming yet
# word ? has stemming ?
# word if has stemming if
# word not has stemming not
# word try has stemming tri
# word to has stemming to
# word book has stemming book
# word it has stemming it
# word ASAP has stemming asap
# word since has stemming sinc
# word booking has stemming book
# word will has stemming will
# word be has stemming be
# word out has stemming out
# word of has stemming of
# word books has stemming book

# %%
word_list = ["friend", "friendship", "friends", "friendships","stabil","destabilize","misunderstanding",
             "railroad","moonlight","football"]
print("{0:20}{1:20}{2:20}".format("Word","Porter Stemmer","lancaster Stemmer"))
for word in word_list:
    print("{0:20}{1:20}{2:20}".format(word,ps.stem(word),ls.stem(word)))
# Out:
# Word                Porter Stemmer      lancaster Stemmer
# friend              friend              friend
# friendship          friendship          friend
# friends             friend              friend
# friendships         friendship          friend
# stabil              stabil              stabl
# destabilize         destabil            dest
# misunderstanding    misunderstand       misunderstand
# railroad            railroad            railroad
# moonlight           moonlight           moonlight
# football            footbal             footbal

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
words = ["cats","cacti","radii","feet","speech",'runner']
for word in words:
  print(lemmatizer.lemmatize(word))
# Out:
# cat
# cactus
# radius
# foot
# speech
# runner

# %%
print(lemmatizer.lemmatize("meeting", "n"))
print(lemmatizer.lemmatize("meeting",'v'))
# Out:
# meeting
# meet

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

sentence = "He was running and eating at same time. He has bad habit of swimming after playing long hours in the Sun."
punctuations="?:!.,;"
sentence_words = word_tokenize(sentence)
for word in sentence_words:
    if word in punctuations:
        sentence_words.remove(word)

# sentence_words
print("{0:20}{1:20}".format("Word","Lemma"))
for word in sentence_words:
    print ("{0:20}{1:20}".format(word,lemmatizer.lemmatize(word)))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Word                Lemma
# He                  He
# was                 wa
# running             running
# and                 and
# eating              eating
# at                  at
# same                same
# time                time
# He                  He
# has                 ha
# bad                 bad
# habit               habit
# of                  of
# swimming            swimming
# after               after
# playing             playing
# long                long
# hours               hour
# in                  in
# the                 the
# Sun                 Sun
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for word in sentence_words:
    print ("{0:20}{1:20}".format(word,lemmatizer.lemmatize(word, pos="v")))
# Out:
# He                  He
# was                 be
# running             run
# and                 and
# eating              eat
# at                  at
# same                same
# time                time
# He                  He
# has                 have
# bad                 bad
# habit               habit
# of                  of
# swimming            swim
# after               after
# playing             play
# long                long
# hours               hours
# in                  in
# the                 the
# Sun                 Sun

# %%
words = ["is","was","be","been","are","were"]

for word in words :
    print(lemmatizer.lemmatize(word))
# Out:
# is
# wa
# be
# been
# are
# were

# %%
words = ["is","was","be","been","are","were"]

for word in words :
    print(lemmatizer.lemmatize(word, pos="v"))
# Out:
# be
# be
# be
# be
# be
# be

# %%
words = ["feet","radii","men","children","carpenter","fighter"]
for word in words :
    print(lemmatizer.lemmatize(word,'n'))
# Out:
# foot
# radius
# men
# child
# carpenter
# fighter

# %%
words = ['الجري','تجري','يجرون','جري','يجري']
for word in words:
    print(word+' --> '+p_stemmer.stem(word))
# Out:
# الجري --> الجري
# تجري --> تجري
# يجرون --> يجرون
# جري --> جري
# يجري --> يجري

# %%
words = ['الجري','تجري','يجرون','جري','يجري']

for word in words:
    print(word+' --> '+s_stemmer.stem(word))
# Out:
# الجري --> الجري
# تجري --> تجري
# يجرون --> يجرون
# جري --> جري
# يجري --> يجري

# %%
from nltk.stem import PorterStemmer , LancasterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()
ls =  LancasterStemmer()

# %%
words = ['الجري','تجري','يجرون','جري','يجري']

# %%
for word in words:
  print(f"word {word} has stemming {ps.stem(word)}")
# Out:
# word الجري has stemming الجري
# word تجري has stemming تجري
# word يجرون has stemming يجرون
# word جري has stemming جري
# word يجري has stemming يجري

# %%
for word in words:
  print(f"word {word} has stemming {ls.stem(word)}")
# Out:
# word الجري has stemming الجري
# word تجري has stemming تجري
# word يجرون has stemming يجرون
# word جري has stemming جري
# word يجري has stemming يجري

# %%
words = ['الجري','تجري','يجرون','جري','يجري']
print("{0:20}{1:20}{2:20}".format("Word","Porter Stemmer","lancaster Stemmer"))
for word in words:
    print("{0:20}{1:20}{2:20}".format(word,ps.stem(word),ls.stem(word)))
# Out:
# Word                Porter Stemmer      lancaster Stemmer
# الجري               الجري               الجري
# تجري                تجري                تجري
# يجرون               يجرون               يجرون
# جري                 جري                 جري
# يجري                يجري                يجري

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
words = ['الجري','تجري','يجرون','جري','يجري']

# %%
for word in words:
  print(lemmatizer.lemmatize(word))
# Out:
# الجري
# تجري
# يجرون
# جري
# يجري
