# %%
# !pip install nltk

# %%
import nltk
nltk.download("stopwords")

from nltk.corpus import stopwords

stop_words = set(stopwords.words("english"))
stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
# ...

# %%
text = "This is a sentence with stop words."
clean_text = [word for word in text.split() if word not in stop_words]
" ".join(clean_text)
# Out:
# 'This sentence stop words.'

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'under', 'never', 'alone', 'noone', 'ca', 'they', 'eleven', 'around', "'ve", 'former', 'quite', 'do', 'when', 'has', 'is', 'therein', 'he', 'indeed', 'that', 'already', 'at', 'toward', 'hundred', 'after', '’d', 'thereupon', 'full', 'whether', 'keep', 'amount', 'well', 'cannot', 'ourselves', 'back', 'you', 'me', 'wherever', 'nothing', 'all', 'seems', 'nor', 'while', 'everything', 'three', 'were', 'can', 'them', 'should', 'hence', 'perhaps', 'afterwards', 'still', 'however', 'was', 'same', 'rather', 'give', 'against', 'thence', 'amongst', 'latterly', 'whatever', 'due', 'meanwhile', 'n‘t', 'often', 'those', 'own', 'someone', 'an', 'be', 'anywhere', '’m', 'name', 'than', 'show', 'became', 'nevertheless', 'moreover', 'from', 'how', 'side', 'via', 'seemed', 'whither', 'during', 'themselves', 'whose', 'each', 'ever', 'myself', "'ll", 'together', 'no', 'seem', 'every', 'beforehand', 'thru', 'used', 'get', 'though', 'are', 'upon', 'as', 'would', 'nine', 'more', 'beside', 'a', "'m", 'of', 'yo
# ...

# %%
nlp.vocab["hello"].is_stop
# Out:
# False

# %%
nlp.vocab["he"].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.add("hello")
nlp.vocab["hello"].is_stop = True

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'under', 'never', 'alone', 'noone', 'ca', 'they', 'eleven', 'around', "'ve", 'former', 'quite', 'do', 'when', 'has', 'is', 'therein', 'he', 'indeed', 'that', 'already', 'at', 'toward', 'hundred', 'after', '’d', 'thereupon', 'full', 'whether', 'keep', 'amount', 'well', 'cannot', 'ourselves', 'back', 'you', 'me', 'wherever', 'nothing', 'all', 'seems', 'nor', 'while', 'everything', 'three', 'were', 'can', 'them', 'should', 'hence', 'perhaps', 'afterwards', 'still', 'however', 'was', 'same', 'rather', 'give', 'against', 'thence', 'amongst', 'latterly', 'whatever', 'due', 'meanwhile', 'n‘t', 'often', 'those', 'own', 'someone', 'an', 'be', 'anywhere', '’m', 'name', 'than', 'show', 'became', 'nevertheless', 'moreover', 'from', 'how', 'side', 'via', 'seemed', 'whither', 'during', 'themselves', 'whose', 'each', 'ever', 'myself', "'ll", 'together', 'no', 'seem', 'every', 'beforehand', 'thru', 'used', 'get', 'though', 'are', 'upon', 'as', 'would', 'nine', 'more', 'beside', 'a', "'m", 'of', 'yo
# ...

# %%
nlp.vocab["hello"].is_stop
# Out:
# True

# %%
nlp.vocab["never"].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove("never")
nlp.vocab["never"].is_stop = False

# %%
nlp.vocab["never"].is_stop
# Out:
# False

# %%
import nltk
nltk.download("stopwords")
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words("english"))
print(len(stop_words))
# Out:
# 198

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
example_sent = "This is a sample sentence, And This showing off the stop words filtration."
tokens = word_tokenize(example_sent)
tokens
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'sentence',
#  ',',
#  'And',
#  'This',
#  'showing',
#  'off',
#  'the',
#  'stop',
#  'words',
#  'filtration',
#  '.']

# %%
filtered_tokens = [word for word in tokens if word not in stop_words]

print(tokens)
print('-'*125)
print(filtered_tokens)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# -----------------------------------------------------------------------------------------------------------------------------
# ['This', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'stop', 'words', 'filtration', '.']

# %%
from nltk.corpus import stopwords

arabic_sw = stopwords.words("arabic")
arabic_sw
# Out:
# ['إذ',
#  'إذا',
#  'إذما',
#  'إذن',
#  'أف',
#  'أقل',
#  'أكثر',
#  'ألا',
#  'إلا',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللاتي',
#  'اللائي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'أم',
#  'أما',
#  'أما',
#  'إما',
#  'أن',
#  'إن',
#  'إنا',
#  'أنا',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'إنما',
#  'إنه',
#  'أنى',
#  'أنى',
#  'آه',
#  'آها',
#  'أو',
#  'أولاء',
#  'أولئك',
#  'أوه',
#  'آي',
#  'أي',
#  'أيها',
#  'إي',
#  'أين',
#  'أين',
#  'أينما',
#  'إيه',
#  'بخ',
#  'بس',
#  'بعد',
#  'بعض',
#  'بك',
#  'بكم',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بين',
#  'بيد',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'ثم',
#  'ثمة',
#  'حاشا',
#  'حبذا',
#  'حتى',
#  'حيث',
#  'حيثما',
#  'حين',
#  'خلا',
#  'دون',
# ...

# %%
len(arabic_sw)
# Out:
# 754

# %%
" ".join(arabic_sw)
# Out:
# 'إذ إذا إذما إذن أف أقل أكثر ألا إلا التي الذي الذين اللاتي اللائي اللتان اللتيا اللتين اللذان اللذين اللواتي إلى إليك إليكم إليكما إليكن أم أما أما إما أن إن إنا أنا أنت أنتم أنتما أنتن إنما إنه أنى أنى آه آها أو أولاء أولئك أوه آي أي أيها إي أين أين أينما إيه بخ بس بعد بعض بك بكم بكم بكما بكن بل بلى بما بماذا بمن بنا به بها بهم بهما بهن بي بين بيد تلك تلكم تلكما ته تي تين تينك ثم ثمة حاشا حبذا حتى حيث حيثما حين خلا دون ذا ذات ذاك ذان ذانك ذلك ذلكم ذلكما ذلكن ذه ذو ذوا ذواتا ذواتي ذي ذين ذينك ريث سوف سوى شتان عدا عسى عل على عليك عليه عما عن عند غير فإذا فإن فلا فمن في فيم فيما فيه فيها قد كأن كأنما كأي كأين كذا كذلك كل كلا كلاهما كلتا كلما كليكما كليهما كم كم كما كي كيت كيف كيفما لا لاسيما لدى لست لستم لستما لستن لسن لسنا لعل لك لكم لكما لكن لكنما لكي لكيلا لم لما لن لنا له لها لهم لهما لهن لو لولا لوما لي لئن ليت ليس ليسا ليست ليستا ليسوا ما ماذا متى مذ مع مما ممن من منه منها منذ مه مهما نحن نحو نعم ها هاتان هاته هاتي هاتين هاك هاهنا هذا هذان هذه هذي هذين هكذا هل هلا هم هما هن هنا 
# ...

# %%
# !pip install arabic-stopwords
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 13.4 MB/s eta 0:00:00
# ...

# %%
import arabicstopwords.arabicstopwords as stp
len(stp.classed_stopwords_list())
# Out:
# 508

# %%
stp.classed_stopwords_list()
# Out:
# dict_keys(['أن', 'إن', 'عل', 'كأن', 'لعل', 'لكن', 'ليت', 'ثنا', 'بيد', 'سوى', 'غير', 'لاسيما', 'أولئك', 'أولئكم', 'أولاء', 'أولالك', 'تان', 'تانك', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'ذا', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذوا', 'ذواتا', 'ذواتي', 'ذوو', 'ذوي', 'ذي', 'ذين', 'ذينك', 'كذلك', 'هؤلاء', 'هاتان', 'هاته', 'هاتي', 'هاتين', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا', 'هنا', 'هناك', 'هنالك', 'أي', 'إذ', 'إذا', 'ابن', 'بعض', 'تجاه', 'تلقاء', 'جميع', 'حسب', 'حيث', 'سبحان', 'شبه', 'شطر', 'كل', 'لعمر', 'لما', 'مثل', 'مع', 'معاذ', 'نحو', 'متى', 'أنى', 'أيان', 'أين', 'بكم', 'بما', 'بماذا', 'بمن', 'كم', 'كيف', 'ما', 'ماذا', 'مما', 'ممن', 'من', 'أينما', 'حيثما', 'كيفما', 'مهما', 'أقل', 'أكثر', 'آها', 'بس', 'حاي', 'صه', 'طاق', 'طق', 'عدس', 'كخ', 'نخ', 'هج', 'وا', 'واها', 'وي', 'آمين', 'آه', 'أف', 'أمامك', 'أوه', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'إيه', 'بخ', 'بطآن', 'بله', 'حذار', 'حي', 'دونك', 'رويدك', 'سرعان', 'شتان',
# ...

# %%
len(stp.stopwords_list())
# Out:
# 13465

# %%
stp.stopwords_list()
# Out:
# ['أن',
#  'أنك',
#  'أنكما',
#  'أنكم',
#  'أنكن',
#  'أننا',
#  'أنها',
#  'أنه',
#  'أنهما',
#  'أنهم',
#  'أنهن',
#  'أني',
#  'بأن',
#  'بأنك',
#  'بأنكما',
#  'بأنكم',
#  'بأنكن',
#  'بأننا',
#  'بأنها',
#  'بأنه',
#  'بأنهما',
#  'بأنهم',
#  'بأنهن',
#  'بأني',
#  'فأن',
#  'فأنك',
#  'فأنكما',
#  'فأنكم',
#  'فأنكن',
#  'فأننا',
#  'فأنها',
#  'فأنه',
#  'فأنهما',
#  'فأنهم',
#  'فأنهن',
#  'فأني',
#  'فبأن',
#  'فبأنك',
#  'فبأنكما',
#  'فبأنكم',
#  'فبأنكن',
#  'فبأننا',
#  'فبأنها',
#  'فبأنه',
#  'فبأنهما',
#  'فبأنهم',
#  'فبأنهن',
#  'فبأني',
#  'فكأن',
#  'فكأنك',
#  'فكأنكما',
#  'فكأنكم',
#  'فكأنكن',
#  'فكأننا',
#  'فكأنها',
#  'فكأنه',
#  'فكأنهما',
#  'فكأنهم',
#  'فكأنهن',
#  'فكأني',
#  'فلأن',
#  'فلأنك',
#  'فلأنكما',
#  'فلأنكم',
#  'فلأنكن',
#  'فلأننا',
#  'فلأنها',
#  'فلأنه',
#  'فلأنهما',
#  'فلأنهم',
#  'فلأنهن',
#  'فلأني',
#  'كأن',
#  'كأنك',
#  'كأنكما',
#  'كأنكم',
#  'كأنكن',
#  'كأننا',
#  'كأنها',
#  'كأنه',
#  'كأنهما',
#  'كأنهم',
#  'كأنهن',
# ...

# %%
stp.is_stop("ممكن")
# Out:
# False

# %%
stp.is_stop("وبتلكم")
# Out:
# True

# %%
stop_words  = ['on','at','with','the','by','to','this','my']

text = 'I went to the university by bus On this monday with My friend at 9:00'

' '.join([i for i in text.split() if   i.lower() not in stop_words])
# Out:
# 'I went university bus monday friend 9:00'
